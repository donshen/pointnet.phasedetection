# %%
import random
import numpy as np
train_ratio = 0.85

# %%
n_class = 9
phases = ['lam','hpc','hpl','bcc','dis','sg','dg','dd','p']
n_points = 1450
n_train = int(n_points*train_ratio)
n_test = n_points - n_train
n_val = 0
train_id = np.zeros((n_train, n_class))
test_id = np.zeros((n_test, n_class))
val_id = np.zeros((n_val, n_class))

for i in range(n_class):
    train_id[:,i] = random.sample(range(1,n_points+1), n_train)
    test_id[:,i] = random.sample(list(set([i for i in range(1,n_points+1)])
                                      - set(train_id[:,i])), n_test)
    val_id[:,i] = random.sample(list(set([i for i in range(1,n_points+1)]) 
                                     - set(train_id[:,i])-set(test_id[:,i])), n_val)

data_train, data_test, data_val = [], [], []

for i in range(len(phases)):
    for j in train_id[:,i]:
        data_train.append('"shape_data/%s/coord_O_%s_%d"' %(phases[i], phases[i], j))
    for j in test_id[:,i]:
        data_test.append('"shape_data/%s/coord_O_%s_%d"' %(phases[i], phases[i], j))
    for j in val_id[:,i]:
        data_val.append('"shape_data/%s/coord_O_%s_%d"' %(phases[i], phases[i], j))

# %%
ftrain = open('shuffled_train_file_list.json','w')
ftrain.write('[')
for k in range(len(data_train)-1):
    ftrain.write(data_train[k] +',')
ftrain.write(data_train[-1]+']')
ftrain.close()

ftest = open('shuffled_test_file_list.json','w')
ftest.write('[')
for k in range(len(data_test)-1):
    ftest.write(data_test[k] +',')
ftest.write(data_test[-1]+']')
ftest.close()

# fval = open('shuffled_val_file_list.json','w')
# fval.write('[')
# for k in range(len(data_val)-1):
#     fval.write(data_val[k] +',')
# fval.write(data_val[-1]+']')
# fval.close()

# %%
n_0 = 1450
n_train_0 = int(n_0*train_ratio)
n_test_0 = n_0 - n_train_0
n_val_0 = 0

n_1 = 1499
n_train_1 = int(n_1*train_ratio)
n_test_1 = n_1 - n_train_1
n_val_1 = 0

n_2 = 1499
n_train_2 = int(n_2*train_ratio)
n_test_2 = n_2 - n_train_2
n_val_2 = 0

n_3 = 1499
n_train_3 = int(n_3*train_ratio)
n_test_3 = n_3 - n_train_3
n_val_3 = 0

n_4 = 1499
n_train_4 = int(n_4*train_ratio)
n_test_4 = n_4 - n_train_4
n_val_4 =0

n_5 = 1499
n_train_5 = int(n_5*train_ratio)
n_test_5 = n_5 - n_train_5
n_val_5 =0

n_6 = 1499
n_train_6 = int(n_6*train_ratio)
n_test_6 = n_6 - n_train_6
n_val_6 =0

n_7 = 1499
n_train_7 = int(n_7*train_ratio)
n_test_7 = n_7 - n_train_7
n_val_7 =0

n_8 = 1499
n_train_8 = int(n_8*train_ratio)
n_test_8 = n_8 - n_train_8
n_val_8 =0

train_id_0 = random.sample(range(1,n_0+1), n_train_0)
test_id_0 = random.sample(list(set([i for i in range(1,n_0+1)])-set(train_id_0)), n_test_0)
val_id_0 = random.sample(list(set([i for i in range(1,n_0+1)])-set(train_id_0)-set(test_id_0)), n_val_0)

train_id_1 = random.sample(range(1,n_1+1), n_train_1)
test_id_1 = random.sample(list(set([i for i in range(1,n_1+1)])-set(train_id_1)), n_test_1)
val_id_1 = random.sample(list(set([i for i in range(1,n_1+1)])-set(train_id_1)-set(test_id_1)), n_val_1)

train_id_2 = random.sample(range(1,n_2+1), n_train_2)
test_id_2 = random.sample(list(set([i for i in range(1,n_2+1)])-set(train_id_2)), n_test_2)
val_id_2 = random.sample(list(set([i for i in range(1,n_2+1)])-set(train_id_2)-set(test_id_2)), n_val_2)

train_id_3 = random.sample(range(1,n_3+1), n_train_3)
test_id_3 = random.sample(list(set([i for i in range(1,n_3+1)])-set(train_id_3)), n_test_3)
val_id_3 = random.sample(list(set([i for i in range(1,n_3+1)])-set(train_id_3)-set(test_id_3)), n_val_3)

train_id_4 = random.sample(range(1,n_4+1), n_train_4)
test_id_4 = random.sample(list(set([i for i in range(1,n_4+1)])-set(train_id_4)), n_test_4)
val_id_4 = random.sample(list(set([i for i in range(1,n_4+1)])-set(train_id_4)-set(test_id_4)), n_val_4)

train_id_5 = random.sample(range(1,n_5+1), n_train_5)
test_id_5 = random.sample(list(set([i for i in range(1,n_5+1)])-set(train_id_5)), n_test_5)
val_id_5 = random.sample(list(set([i for i in range(1,n_5+1)])-set(train_id_5)-set(test_id_5)), n_val_5)

train_id_6 = random.sample(range(1,n_6+1), n_train_6)
test_id_6 = random.sample(list(set([i for i in range(1,n_6+1)])-set(train_id_6)), n_test_6)
val_id_6 = random.sample(list(set([i for i in range(1,n_6+1)])-set(train_id_6)-set(test_id_6)), n_val_6)

train_id_7 = random.sample(range(1,n_7+1), n_train_7)
test_id_7 = random.sample(list(set([i for i in range(1,n_7+1)])-set(train_id_7)), n_test_7)
val_id_7 = random.sample(list(set([i for i in range(1,n_7+1)])-set(train_id_7)-set(test_id_7)), n_val_7)

train_id_8 = random.sample(range(1,n_8+1), n_train_8)
test_id_8 = random.sample(list(set([i for i in range(1,n_8+1)])-set(train_id_8)), n_test_8)
val_id_8 = random.sample(list(set([i for i in range(1,n_8+1)])-set(train_id_8)-set(test_id_8)), n_val_8)

# %%
(data_train, data_test, data_val) = ([],[],[])
for i in train_id_0:
    data_train.append('"shape_data/lam/coord_O_lam_%d"' %i)
for j in train_id_1:
    data_train.append('"shape_data/hpc/coord_O_hpc_%d"' %j)    
for k in train_id_2:   
    data_train.append('"shape_data/hpl/coord_O_hpl_%d"' %k)
for q in train_id_3:   
    data_train.append('"shape_data/bcc/coord_O_bcc_%d"' %q)    
for l in train_id_4:   
    data_train.append('"shape_data/dis/coord_O_dis_%d"' %l)
for m in train_id_5:   
    data_train.append('"shape_data/sg/coord_O_sg_%d"' %m)
for n in train_id_6:   
    data_train.append('"shape_data/dg/coord_O_dg_%d"' %n)
for o in train_id_7:   
    data_train.append('"shape_data/dd/coord_O_dd_%d"' %o)
for p in train_id_8:   
    data_train.append('"shape_data/p/coord_O_p_%d"' %p)
    
for i in test_id_0:
    data_test.append('"shape_data/lam/coord_O_lam_%d"' %i)
for j in test_id_1:
    data_test.append('"shape_data/hpc/coord_O_hpc_%d"' %j) 
for k in test_id_2:   
    data_test.append('"shape_data/hpl/coord_O_hpl_%d"' %k)
for q in test_id_3:   
    data_test.append('"shape_data/bcc/coord_O_bcc_%d"' %q)
for l in test_id_4:   
    data_test.append('"shape_data/dis/coord_O_dis_%d"' %l)
for m in test_id_5:   
    data_test.append('"shape_data/sg/coord_O_sg_%d"' %m) 
for n in test_id_6:   
    data_test.append('"shape_data/dg/coord_O_dg_%d"' %n) 
for o in test_id_7:   
    data_test.append('"shape_data/dd/coord_O_dd_%d"' %o) 
for p in test_id_8:   
    data_test.append('"shape_data/p/coord_O_p_%d"' %p) 
    
for i in val_id_0:
    data_val.append('"shape_data/lam/coord_O_lam_%d"' %i)
for j in val_id_1:
    data_val.append('"shape_data/hpc/coord_O_hpc_%d"' %j) 
for k in val_id_2:   
    data_val.append('"shape_data/hpl/coord_O_hpl_%d"' %k)
for q in val_id_3:   
    data_val.append('"shape_data/bcc/coord_O_bcc_%d"' %q)    
for l in val_id_4:   
    data_val.append('"shape_data/dis/coord_O_dis_%d"' %l)
for m in val_id_5:   
    data_val.append('"shape_data/sg/coord_O_sg_%d"' %m)    
for n in val_id_6:   
    data_val.append('"shape_data/dg/coord_O_dg_%d"' %n)    
for o in val_id_7:   
    data_val.append('"shape_data/dd/coord_O_dd_%d"' %o)    
for p in val_id_8:   
    data_val.append('"shape_data/p/coord_O_p_%d"' %p)
